# %% [markdown]
# UNEMPLOYMENT ANALYSIS USING PYTHON
#
# The number of unemployed persons as a percentage of the total labour force is used to calculate the unemployment rate, which is used to assess unemployment.Since the unemployment rate hass increased significantly in recent years, examining it can help us identify which regions or industries inthe nation require greater growth. During COVID-19,we'll examine the unemployment rate in the Indian stated.
#
# Steps
#
# 1.Importing required libraries
# 2.Loading of dataset
# 3.Display Summary Statistics
# 4.Data Visualization Used plots are pair plots,histograms,scatter plots,line plots
# 5.Correlation Matrix
# 6.Analysis with Sunburst Plot
#
# Python Plotly Library is an open-source library that can be used for data visualization and understanding data simply and easily. Plotly supports various types of plots like line charts,scatter plots,histograms,cox plots,etc.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
#data first file Unemployment in indian
df = pd.read_csv('/content/Unemployment in India.csv')
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
#data of the second file Unemployment_Rate_upto_11_2020.csv
df1 =pd.read_csv('/content/Unemployment_Rate_upto_11_2020.csv')
df1
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
#First and Last rows of Unemployment in India dataset
print("Rows from start are: ")
print(df.head(6))
print("\n")
print("Rows from bottom: ")
print(df.tail(8))
# Out:
# Rows from start are:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
# 5  Andhra Pradesh   31-10-2019    Monthly                              3.52
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# ...

# %%
#First and Last rows of the Unemployment rate upto 2020 dataset
print("Rows from start are:\n")
print(df1.head(6))
print("Rows from ending are:\n")
df1.tail(7)
# Out:
# Rows from start are:
#
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
# 5  Andhra Pradesh   30-06-2020          M                              3.31
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# ...

# %%
#shape size statistics and info of df
print("The sahpe of the df is",df.shape)
print("Thhe Size of the data is",df.size)
print("\n")
print("The Info:\n")
print("The statitics :\n")
df.describe()
# Out:
# The sahpe of the df is (768, 7)
# Thhe Size of the data is 5376
#
#
# The Info:
#
# The statitics :
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# ...

# %%
#shape size statistics and info of df
print("The shape of the df is",df1.shape)
print("The Size of the data is",df1.size)
print("\n")
print("The Info:\n")
df1.info()
print("The statistics :\n")
df1.describe()
# Out:
# The shape of the df is (267, 9)
# The Size of the data is 2403
#
#
# The Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# ...

# %% [markdown]
# DATA CLEANING

# %%
dat = df.isnull()
print('The null values in the middle are :\n')
dat[361:373]
# Out:
# The null values in the middle are :
#      Region   Date   Frequency   Estimated Unemployment Rate (%)  \
# 361    True   True        True                              True
# 362    True   True        True                              True
# 363    True   True        True                              True
# 364    True   True        True                              True
# 365    True   True        True                              True
# 366    True   True        True                              True
# 367    True   True        True                              True
# 368    True   True        True                              True
# 369    True   True        True                              True
# 370    True   True        True                              True
# 371    True   True        True                              True
# 372    True   True        True                              True
#
#       Estimated Employed   Estimated Labour Participation Rate (%)  Area
# ...

# %%
print("The null values at the end are:\n")
dat[756:770]
# Out:
# The null values at the end are:
#      Region   Date   Frequency   Estimated Unemployment Rate (%)  \
# 756    True   True        True                              True
# 757    True   True        True                              True
# 758    True   True        True                              True
# 759    True   True        True                              True
# 760    True   True        True                              True
# 761    True   True        True                              True
# 762    True   True        True                              True
# 763    True   True        True                              True
# 764    True   True        True                              True
# 765    True   True        True                              True
# 766    True   True        True                              True
# 767    True   True        True                              True
#
#       Estimated Employed   Estimated Labour Participation Rate (%)  Area
# ...

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
#for the dataset 2 checking for the null values
df1.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
#changing the columns to remove the empty spaces for data set 1
df.columns = ['State','Date','Frequency','Estimated Unemployment Rate (%)','Estimated Employed','Estimated Labour Participation Rate (%)','Area']

# %%
#converting the columns to remove the empty spaces foe data set 1
df.columns = ['State','Date','Frequency','Estimated Unemployment Rate (%)','Estimated Employed','Estimated Labour Participation Rate (%)','Area']

# %%
#converting the data into to datatime data set1
df.isetitem(df.columns.get_loc('Date'),pd.to_datetime(df['Date']))
df
# Out:
# <ipython-input-17-c84e4efcac36>:2: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df.isetitem(df.columns.get_loc('Date'),pd.to_datetime(df['Date']))
#               State       Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1    Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2    Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3    Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4    Andhra Pradesh 2019-09-30   Monthly                             5.17
# ..              ...        ...       ...                              ...
# 749     West Bengal 2020-02-29   Monthly                             7.55
# 750     West Bengal 2020-03-31   Monthly                             6.67
# ...

# %%
# changing the columns names and converting the date into datetime for data set 2
df1.columns = ['State','Date','Frequency','Estimated Unemployment Rate (%)','Estimated Employed','Estimated Labour Participation Rate (%)','Region','longitude','latitude']
df1.isetitem(df1.columns.get_loc('Date'),pd.to_datetime(df1['Date']))
df1
# Out:
# <ipython-input-18-ed8cc550505a>:3: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df1.isetitem(df1.columns.get_loc('Date'),pd.to_datetime(df1['Date']))
#               State       Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2020-01-31         M                             5.48
# 1    Andhra Pradesh 2020-02-29         M                             5.83
# 2    Andhra Pradesh 2020-03-31         M                             5.79
# 3    Andhra Pradesh 2020-04-30         M                            20.51
# 4    Andhra Pradesh 2020-05-31         M                            17.43
# ..              ...        ...       ...                              ...
# 262     West Bengal 2020-06-30         M                             7.29
# 263     West Bengal 2020-07-31         M                             6.83
# ...

# %% [markdown]
# DATA INTERPRETATION
#
# For SET-1
#
# 1.State with highest Unemployment Rate

# %%
print(df['State'].value_counts().idxmax())
# Out:
# Andhra Pradesh

# %% [markdown]
# 2.State with Lowest Unemployment Rate

# %%
print(df['State'].value_counts().idxmax())
# Out:
# Andhra Pradesh

# %% [markdown]
# 3.Area with the Highest Unemployment Rate

# %%
print(df['Area'].value_counts().idxmin())
# Out:
# Rural

# %%
#adding month number and month name and year columns for analysis

#adding the month_number
df.loc[:,'Month_num'] = pd.to_datetime(df['Date']).dt.month
#addding the month name
df.loc[:,'Month_name'] = pd.to_datetime(df['Date']).dt.month_name()
#adding the year
df.loc[:,'Year'] = pd.to_datetime(df['Date']).dt.year
df
# Out:
# <ipython-input-22-a8cf01734594>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'Month_num'] = pd.to_datetime(df['Date']).dt.month
# <ipython-input-22-a8cf01734594>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'Month_name'] = pd.to_datetime(df['Date']).dt.month_name()
# <ipython-input-22-a8cf01734594>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# 5.Month with Highest Unemployment Rate

# %%
print(df['Month_name'].value_counts().idxmax())
# Out:
# May

# %% [markdown]
# 6.Month with Lowest Unemployment Rate

# %%
print(df['Month_name'].value_counts().idxmin())
# Out:
# April

# %% [markdown]
# 7.Year with Highest Unemployment Rate either 2019 or 2020

# %%
print(df['Year'].value_counts().idxmax())
# Out:
# 2019

# %% [markdown]
# For set 2
#
# 1.State with Highest Unemployment Rate

# %%
print(df1['State'].value_counts().idxmax())
# Out:
# Andhra Pradesh

# %% [markdown]
# 2.State with Lowest Unemployment Rate

# %%
print(df1['State'].value_counts().idxmin())
# Out:
# Sikkim

# %% [markdown]
# 3.Region with highest Unemployment Rate

# %%
print(df1['Region'].value_counts().idxmax())
# Out:
# North

# %% [markdown]
# 4.Region with the Lowest Unemployment Rate

# %%
print(df1['Region'].value_counts().idxmin())
# Out:
# Northeast

# %% [markdown]
# DATA VISUALISATION
#
# for set-1
#
# TOP 15 STATES WITH HIGHEST UNEMPLOYMENT RATE

# %%
#data1  = df[['States','Estimated Unemployment Rate(%)']].grouptby('state').sum().sort_values(by='Estimated Unemployment Rate(%)',ascending=False)
data1 = df[['State','Estimated Unemployment Rate (%)']].groupby('State').sum().sort_values(by='Estimated Unemployment Rate (%)',ascending=False)

data1.head(15)
# Out:
#                   Estimated Unemployment Rate (%)
# State
# Tripura                                    793.81
# Haryana                                    735.93
# Jharkhand                                  576.38
# Bihar                                      529.71
# Himachal Pradesh                           519.13
# Delhi                                      461.87
# Rajasthan                                  393.63
# Uttar Pradesh                              351.44
# Jammu & Kashmir                            339.96
# Punjab                                     336.87
# Kerala                                     283.47
# Puducherry                                 265.59
# Tamil Nadu                                 259.96
# Chhattisgarh                               258.73
# West Bengal                                227.49

# %%
plot = px.bar(data1, x=data1.index, y="Estimated Unemployment Rate (%)", title = 'Top 15 States with Highest Unemployment Rate',color=data1.index)
plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# pie Chart

# %%
plot = px.pie(df,values='Estimated Unemployment Rate (%)',names = df['State'],title="UNEMPLOYMENT RATE IN YEAR 2019-2020(state wise)")
plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot = px.pie(df,values='Estimated Unemployment Rate (%)',names= df['Month_name'],title="UNEMPLOYMENT RATE IN YEAR 2019-2020(Monthwise)")
plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Unemployment Rate based on months

# %%
data2 = df[['Month_name','Estimated Unemployment Rate (%)']].groupby('Month_name').sum().sort_values(by='Estimated Unemployment Rate (%)',ascending=False)
data2
# Out:
#             Estimated Unemployment Rate (%)
# Month_name
# May                                 1747.85
# April                               1205.72
# June                                1097.56
# March                                556.43
# October                              544.55
# November                             542.76
# February                             528.13
# January                              527.39
# August                               510.81
# December                             503.36
# July                                 487.83
# September                            470.69

# %%
plot = px.bar(data2,x=data2.index,y='Estimated Unemployment Rate (%)',title ='Top months of Highest Unemployment Rate',color=data2.index)
plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Estimated unemployment Rate year month and area

# %%
data3 = df[["Month_name","Year","Area","Estimated Unemployment Rate (%)"]].groupby(['Year', "Month_name",'Area']).mean()
#data3 = df[["Month_name","Year","Area","Estimated Unemployment Rate (%)"]].groupby(["Year","Month_name","Area"]).mean()
data3
# Out:
#                        Estimated Unemployment Rate (%)
# Year Month_name Area
# 2019 August     Rural                         8.503077
#                 Urban                        10.730741
#      December   Rural                         8.233600
#                 Urban                        10.625714
#      July       Rural                         7.741923
#                 Urban                        10.233571
#      June       Rural                         8.201154
#                 Urban                        10.326786
#      May        Rural                         7.068077
#                 Urban                        10.551429
#      November   Rural                         8.432222
#                 Urban                        11.253214
#      October    Rural                         9.051111
#                 Urban                        10.720357
#      September  Rural                         7.036800
#                 Urban                        10.917407
# ...

# %%
df
# Out:
#               State       Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1    Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2    Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3    Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4    Andhra Pradesh 2019-09-30   Monthly                             5.17
# ..              ...        ...       ...                              ...
# 749     West Bengal 2020-02-29   Monthly                             7.55
# 750     West Bengal 2020-03-31   Monthly                             6.67
# 751     West Bengal 2020-04-30   Monthly                            15.63
# 752     West Bengal 2020-05-31   Monthly                            15.22
# 753     West Bengal 2020-06-30   Monthly                             9.86
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area  \
# ...

# %% [markdown]
# Set1 Data Visualisation
#
# 1.Correlation Matrix

# %%
cor = df.corr(numeric_only=True)
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# 2.Histograms

# %%
#fig = plt,figure(figsize=(10,10)
sns.histplot(x='Estimated Unemployment Rate (%)',data=df,kde=True,hue='Area')
plt.title('Unemployment according to Area')
plt.xlabel('Unemployment Rate')
plt.show()

# %%
#fig = plt.figure(figsize = (5,5))
sns.lineplot(y='Estimated Unemployment Rate (%)', x = 'Date',data=df)
plt.xlabel('Date')
plt.xticks(rotation=90)
plt.ylabel('Unemployment Rate')
plt.show()

# %%
#fig = plt.figure(figsize = (30,15))
sns.histplot(x='Estimated Labour Participation Rate (%)',data=df,kde=True,hue='Area')
plt.title('Labour Participation according to Area')
plt.xlabel('Labour Participation Rate')
plt.show()

# %%
#fig = plt.figure(figsize = (7,7))
sns.lineplot(y='Estimated Labour Participation Rate (%)',x='Date',data=df)
plt.title('labour Participation according to Date')
plt.xlabel('Date')
plt.xticks(rotation=90)
plt.ylabel('Labour Participation Rate')
plt.show()

# %% [markdown]
# for data set 2
#
# TOP 15 STATES WITH HIGHEST UNEMPLOYMENT RATE

# %%
data6 = df1[['State','Estimated Unemployment Rate (%)']].groupby('State').sum().sort_values(by='Estimated Unemployment Rate (%)',ascending=False)
data6.head(15)
# Out:
#                   Estimated Unemployment Rate (%)
# State
# Haryana                                    274.77
# Tripura                                    250.55
# Jharkhand                                  195.39
# Bihar                                      194.71
# Delhi                                      184.14
# Puducherry                                 179.42
# Himachal Pradesh                           160.65
# Rajasthan                                  158.68
# Jammu & Kashmir                            148.30
# Tamil Nadu                                 121.87
# Goa                                        121.67
# Punjab                                     119.81
# Uttarakhand                                111.56
# West Bengal                                101.92
# Uttar Pradesh                               97.37
